# %%
from src.api import cliente_api_clima

# %%
empresas = [
    "CNFL",
    "COOPESANTOS",
    "COOPELESCA",
    "COOPEGUANACASTE",
    "COOPEALFARORUIZ",
    "ESPH",
    "JASEC",
    "ICE"
]

# %%
clima_cliente = cliente_api_clima.ClienteAPI()
clima = clima_cliente.obtener_todas_empresas(empresas, 2019, 2025)
# Out:
# [1/8] Descargando datos de clima para: CNFL...
# [1/8] CNFL completado.
# [2/8] Descargando datos de clima para: COOPESANTOS...
# [2/8] COOPESANTOS completado.
# [3/8] Descargando datos de clima para: COOPELESCA...
# [3/8] COOPELESCA completado.
# [4/8] Descargando datos de clima para: COOPEGUANACASTE...
# [4/8] COOPEGUANACASTE completado.
# [5/8] Descargando datos de clima para: COOPEALFARORUIZ...
# [5/8] COOPEALFARORUIZ completado.
# [6/8] Descargando datos de clima para: ESPH...
# [6/8] ESPH completado.
# [7/8] Descargando datos de clima para: JASEC...
# [7/8] JASEC completado.
# [8/8] Descargando datos de clima para: ICE...
# [8/8] ICE completado.

# %%
from src.eda.ProcesadorEDA import ProcesadorEDA

# %%
procesador_clima = ProcesadorEDA()

# %%
procesador_clima.df = clima

# %%
procesador_clima.df
# Out:
#     Empresa   Año  Mes        T2M     WS10M   CLOUD_AMT       RH2M    T2M_MAX  \
# 0      CNFL  2019    1  22.740000  1.880000   31.883333  76.210000  29.750000
# 1      CNFL  2019    2  24.370000  1.690000   31.976667  64.710000  33.020000
# 2      CNFL  2019    3  25.260000  2.050000   36.296667  62.050000  33.590000
# 3      CNFL  2019    4  25.510000  1.370000   67.026667  67.440000  33.700000
# 4      CNFL  2019    5  23.840000  1.070000   91.280000  87.590000  31.740000
# ..      ...   ...  ...        ...       ...         ...        ...        ...
# 667     ICE  2025    8  24.766667  1.603333   81.026667  86.006667  28.763333
# 668     ICE  2025    9  24.733333  1.353333   88.203333  87.120000  29.210000
# 669     ICE  2025   10  24.183333  1.676667   87.320000  89.300000  27.986667
# 670     ICE  2025   11  24.100000  2.006667   75.770000  88.473333  28.153333
# 671     ICE  2025   12  23.803333  2.323333 -999.000000  84.783333  28.003333
#
#        T2M_MIN    CLOUD_OD  GWETROOT         TS  PRECTOTCORR  \
# 0    17.520000    3.726667  0.550000  23.600000     0.220000
# 1    18.100000    4.166667  0.440000  25.980000     0.550000
# 2    19.560000    4.506667  0.410000  27.130000     1.600000
# 3    19.990000    4.030000  0.410000  27.020000     2.600000
# 4    19.970000    8.220000  0.580000  24.400000    12.670000
# ..         ...         ...       ...        ...          ...
# 667  20.820000    6.410000  0.906667  24.966667     5.540000
# 668  21.800000    6.573333  0.923333  25.040000    11.396667
# 669  21.620000    6.976667  0.986667  24.610000    13.706667
# 670  20.090000    6.563333  0.950000  24.243333     7.266667
# 671  20.633333 -999.000000  0.863333  23.913333     4.636667
#
#      ALLSKY_SFC_SW_DWN         PS     T2MWET  ALLSKY_SFC_SW_DIFF  \
# 0             5.615333  93.770000  20.370000            1.531533
# 1             6.073000  93.740000  20.460000            1.746000
# 2             6.410700  93.750000  20.940000            1.866800
# 3             5.744567  93.760000  21.870000            2.417100
# 4             4.362733  93.720000  22.640000            2.378133
# ..                 ...        ...        ...                 ...
# 667           4.647500  95.793333  23.423333            2.369267
# 668           4.385267  95.756667  23.510000            2.327733
# 669           4.133533  95.676667  23.183333            2.216400
# 670           4.011733  95.716667  23.023333            1.847233
# 671        -999.000000  95.736667  22.350000         -999.000000
#
#      ALLSKY_SFC_LW_DWN
# 0             9.337467
# 1             9.366233
# 2             9.552867
# 3             9.840867
# 4             9.932333
# ..                 ...
# 667           9.546933
# 668           9.604133
# 669           9.546000
# 670           9.477000
# 671        -999.000000
#
# [672 rows x 18 columns]
