# %%
from src.api import cliente_api_clima

# %%
empresas = [
    "CNFL",
    "COOPESANTOS",
    "COOPELESCA",
    "COOPEGUANACASTE",
    "COOPEALFARORUIZ",
    "ESPH",
    "JASEC",
    "ICE"
]

# %%
clima_cliente = cliente_api_clima.ClienteAPI()
clima = clima_cliente.obtener_todas_empresas( inicio=2019, fin=2025)

# %%
from eda.ProcesadorEDA import ProcesadorEDA

# %%
procesador_clima = ProcesadorEDA()

# %%
procesador_clima.df = clima

# %%
    procesador_clima.df
# Out:
#       id_Objecto   centralElectrica  \
# 0              8  P.E VALLE CENTRAL
# 1              8  P.E VALLE CENTRAL
# 2              8  P.E VALLE CENTRAL
# 3              8  P.E VALLE CENTRAL
# 4              8  P.E VALLE CENTRAL
# ...          ...                ...
# 3451          34   TORO III (JASEC)
# 3452          34   TORO III (JASEC)
# 3453          34   TORO III (JASEC)
# 3454          34   TORO III (JASEC)
# 3455          34   TORO III (JASEC)
#
#                                                operador Empresa  coordenadaX  \
# 0                COMPAÑIA NACIONAL DE FUERZA Y LUZ S.A.    CNFL   -84.198866
# 1                COMPAÑIA NACIONAL DE FUERZA Y LUZ S.A.    CNFL   -84.198866
# 2                COMPAÑIA NACIONAL DE FUERZA Y LUZ S.A.    CNFL   -84.198866
# 3                COMPAÑIA NACIONAL DE FUERZA Y LUZ S.A.    CNFL   -84.198866
# 4                COMPAÑIA NACIONAL DE FUERZA Y LUZ S.A.    CNFL   -84.198866
# ...
